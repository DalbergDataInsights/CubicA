# %%
# Install requests library if you dont have it already
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\denys\appdata\local\programs\python\python37-32\lib\site-packages (2.20.1)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\denys\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\denys\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\denys\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\denys\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (1.24.1)
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# handling imports
import requests
import base64
from datetime import datetime, timedelta

# %%
# keys and tokens
# !!! below is Denys Sementsov DDI Trial key for the aWhere api
consumer_key = "*******"
consumer_secret = "******"
awhere_uri = "https://api.awhere.com/oauth/token"
api_host = "https://api.awhere.com/"

# %%
# requesting token for api usage
# handling request header
# encoding key and secret
to_encode = consumer_key + ":" + consumer_secret
key_secret_encoded = base64.b64encode(to_encode.encode("utf-8"))
request_header = {'Content-Type': 'application/x-www-form-urlencoded',
                 'Authorization': b'Basic '+key_secret_encoded}

# %%
request_header
# Out:
# {'Content-Type': 'application/x-www-form-urlencoded',
#  'Authorization': b'Basic dnFwMVJla2t3UHlHWUhwcmxqcVBxR3ZDbmVLT0VxSlU6cThmdnE5QVo5YVkxY3BOdA=='}

# %%
# handling request body
request_body = { 'grant_type':'client_credentials'}

# %%
request_body
# Out:
# {'grant_type': 'client_credentials'}

# %%
# getting token
token = requests.post(awhere_uri, data=request_body, headers=request_header)
# marking the time of the 
token_expiry = datetime.now() + timedelta(seconds=token.json().get('expires_in', 123123123123))

# %%
# review of the token
token.json()
# Out:
# {'access_token': 'Y2btMkk2NjQpyk4fznGLArufFAiY', 'expires_in': 3599}

# %%
# generating api request
# header 
api_header = {'Authorization' : 'Bearer ' + token.json().get('access_token')}

# %%
api_header
# Out:
# {'Authorization': 'Bearer Y2btMkk2NjQpyk4fznGLArufFAiY'}

# %% [markdown]
# ### aWhere weather data
# - Nice developer community
# - R library
# - Fields available: temp, precipitation, solar energy, wind, relative humidity
# - Sources agriculture-focused ground stations, doppler radar, public and exclusive satelites
# - Hyperlocal (with +-.68C error) with 75% confidence band
# - 1-4 km for weather, 11-25km satelite resolution
# - Accumulated values!
# - 50 fields
# - 50(month)/150(year)/750(3 years) USD perMo
#
# ##### We request reatlime data by sending GET request to api, no body required
#
# ## Request by location:
# ### For actual weather observations:
# /v2/weather/locations/{latitude},{longitude}/observations
#
# /v2/weather/locations/{latitude},{longitude}/observations/{singleDate}
#
# /v2/weather/locations/{latitude},{longitude}/observations/{startDate},{endDate}
#
# ### For forecasts:
# /v2/weather/locations/{latitude},{longitude}/forecasts
#
# /v2/weather/locations/{latitude},{longitude}/forecasts/{singleDate}
#
# /v2/weather/locations/{latitude},{longitude}/forecasts/{startDate},{endDate}
#
# ## Request by field:
#
# ### Daily observed weather
# /v2/weather/fields/{fieldId}/observations
#
# /v2/weather/fields/{fieldId}/observations/{singleDate}
#
# /v2/weather/fields/{fieldId}/observations/{startDate},{endDate}
#
# ### Forecasts
# /v2/weather/fields/{fieldId}/forecasts
#
# /v2/weather/fields/{fieldId}/forecasts/{singleDate}
#
# /v2/weather/fields/{fieldId}/forecasts/{startDate},{endDate}
#
# ### Current conditions
# /v2/weather/fields/{fieldId}/currentconditions
#
# #### aWhere actually supports very convenient batch jobs options where it processes many requests with a single request query, but this is beyond the scope of this notebook
#
# #### Date format YYY-MM-dd

# %% [markdown]
# ### Response format:
# ```json
# {
#     "dateTime":"{timestamp}",
#     "location":":{
#         "latitude":{latitude},
#         "longitude":{longitude},
#         "fieldId":"{fieldId}",
#         "nearestStation":{
#             "distance":{distance},
#             "units":"{distanceUnits}",
#             "bearing":{bearingDegrees}
#             }
#         },
#     "conditionsCode":"{conditionsCode}",
#     "conditionsText":"{conditionsText}",
#     "temperature":{
#         "amount":{temperature},
#         "units":"{tempUnits}"
#         },
#     "precipitation":{
#         "amount":{precipitation},
#         "units":"{precipUnits}"
#         },
#     "solar":{
#         "amount":{solar},
#         "units":"{solarUnits}"
#         },
#     "relativeHumidity":{
#         "amount":{humidity}
#         },
#     "wind":{
#         "amount":{wind},
#         "units":"{windUnits}",
#         "bearing":"{windBearing}",
#         "direction":"{windDirection}",
#         },
#     "_links":{
#         "self":{"href":"{selfLink}"},
#         "curies":[{
#             "name":"awhere",
#             "href":"http://awhere.com/rels/{rel}",
#             "templated":true
#             }],
#         "awhere:field":{"href":"{fieldLink}"}
#         }
# }```

# %% [markdown]
# # Textual description of some fields returns
# <table class="three-cols"><tbody><tr><th>Digit</th>
#             <th>Textual Description</th>
#             <th>Constraints / Qualifications</th>
#         </tr><tr><td class="table-subheading" colspan="3">Cloud Conditions (First Digit)</td>
#         </tr><tr><td>X</td>
#             <td>Cloud Conditions Not Available</td>
#             <td>Weather stations do a poor job of reporting cloud cover in real time, therefore these codes do not include the cloud conditions like the forecast API does. In it's place, we return an <code>X</code> as a placeholder.</td>
#         </tr><tr><td class="table-subheading" colspan="3">Rain Conditions (Second Digit)</td>
#         </tr><tr><td>X</td>
#             <td>Rain Not Reported</td>
#             <td>The reporting station did not report a rain condition.</td>
#         </tr><tr><td>1</td>
#             <td>No Rain</td>
#             <td>No trace of rain/precipitation.</td>
#         </tr><tr><td>2</td>
#             <td>Light Rain</td>
#             <td>Trace amounts up to 2.54mm/hour.</td>
#         </tr><tr><td>3</td>
#             <td>Moderate Rain</td>
#             <td>2.55mm/hour to 7.62mm/hour of rainfall.</td>
#         </tr><tr><td>4</td>
#             <td>Heavy Rain</td>
#             <td>More than 7.62mm/hour of rainfall.</td>
#         </tr><tr><td class="table-subheading" colspan="3">Wind Conditions (Third Digit)</td>
#         </tr><tr><td>X</td>
#             <td>Wind Not Reported</td>
#             <td>The reporting station did not report a wind condition.</td>
#         </tr><tr><td>1</td>
#             <td>Light Wind / Calm</td>
#             <td>0–8 km/hr</td>
#         </tr><tr><td>2</td>
#             <td>Moderate Wind</td>
#             <td>8.01–32 km/hr</td>
#         </tr><tr><td>3</td>
#             <td>Windy</td>
#             <td>32.01–48 km/hr</td>
#         </tr><tr><td>4</td>
#             <td>Very Windy</td>
#             <td>48.01–64 km/hr</td>
#         </tr><tr><td>5</td>
#             <td>Strong Winds</td>
#             <td>64.01–88 km/hr</td>
#         </tr><tr><td>6</td>
#             <td>Hurricane Force</td>
#             <td>More than 88 km/hr</td>
#         </tr></tbody></table></div>

# %% [markdown]
# #### Although aWhere has pretty high resoulution, it makes sense for us to define a custom grid and use that for reference
# #### grid of 25/25km should be sufficient for our needs

# %%
api_request = api_host + "/v2/weather/locations/0.25,32/observations/2018-01-01, 2018-12-31" # somewhere in the middle of kampala
response = requests.get(api_request, headers=api_header)
response.json()
# Out:
# {'observations': [{'date': '2018-01-01',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 26.209999084472656,
#     'min': 19.81999969482422,
#     'units': 'C'},
#    'precipitation': {'amount': 0.675000011920929, 'units': 'mm'},
#    'solar': {'amount': 3743.065185546875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.25, 'min': 57.84000015258789},
#    'wind': {'morningMax': 3.6218745708465576,
#     'dayMax': 5.213216781616211,
#     'average': 2.4703385829925537,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-01'}}},
#   {'date': '2018-01-02',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 26.81999969482422,
#     'min': 18.969999313354492,
#     'units': 'C'},
#    'precipitation': {'amount': 2.700000047683716, 'units': 'mm'},
#    'solar': {'amount': 5569.0615234375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 86.41999816894531, 'min': 50.529998779296875},
#    'wind': {'morningMax': 2.4579761028289795,
#     'dayMax': 3.074984312057495,
#     'average': 1.4747509956359863,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-02'}}},
#   {'date': '2018-01-03',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 26.729999542236328,
#     'min': 19.100000381469727,
#     'units': 'C'},
#    'precipitation': {'amount': 0.925000011920929, 'units': 'mm'},
#    'solar': {'amount': 5614.287109375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 97.33000183105469, 'min': 48.630001068115234},
#    'wind': {'morningMax': 7.108032703399658,
#     'dayMax': 7.20290994644165,
#     'average': 3.318807363510132,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-03'}}},
#   {'date': '2018-01-04',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 24.709999084472656,
#     'min': 18.350000381469727,
#     'units': 'C'},
#    'precipitation': {'amount': 0.25, 'units': 'mm'},
#    'solar': {'amount': 3695.746826171875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 92.69999694824219, 'min': 60.060001373291016},
#    'wind': {'morningMax': 3.7936816215515137,
#     'dayMax': 6.3288187980651855,
#     'average': 3.277819871902466,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-04'}}},
#   {'date': '2018-01-05',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 27.309999465942383,
#     'min': 18.850000381469727,
#     'units': 'C'},
#    'precipitation': {'amount': 0.375, 'units': 'mm'},
#    'solar': {'amount': 6292.6171875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.83000183105469, 'min': 53.970001220703125},
#    'wind': {'morningMax': 5.630353927612305,
#     'dayMax': 6.838536262512207,
#     'average': 3.286362886428833,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-05'}}},
#   {'date': '2018-01-06',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 27.729999542236328,
#     'min': 18.010000228881836,
#     'units': 'C'},
#    'precipitation': {'amount': 0.4749999940395355, 'units': 'mm'},
#    'solar': {'amount': 5547.62353515625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.1500015258789, 'min': 46.470001220703125},
#    'wind': {'morningMax': 2.6881399154663086,
#     'dayMax': 3.2687878608703613,
#     'average': 2.112917184829712,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-06'}}},
#   {'date': '2018-01-07',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 26.530000686645508,
#     'min': 17.8799991607666,
#     'units': 'C'},
#    'precipitation': {'amount': 0.10000000149011612, 'units': 'mm'},
#    'solar': {'amount': 6477.30126953125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 86.18000030517578, 'min': 35.130001068115234},
#    'wind': {'morningMax': 6.125941276550293,
#     'dayMax': 6.163215637207031,
#     'average': 3.517986536026001,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-07'}}},
#   {'date': '2018-01-08',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.25, 'min': 19.18000030517578, 'units': 'C'},
#    'precipitation': {'amount': 1.2999999523162842, 'units': 'mm'},
#    'solar': {'amount': 6507.8193359375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 92.18000030517578, 'min': 37.11000061035156},
#    'wind': {'morningMax': 5.65039587020874,
#     'dayMax': 9.621872901916504,
#     'average': 4.006948471069336,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-08'}}},
#   {'date': '2018-01-09',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.600000381469727,
#     'min': 18.540000915527344,
#     'units': 'C'},
#    'precipitation': {'amount': 0.6499999761581421, 'units': 'mm'},
#    'solar': {'amount': 6504.1611328125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 90.93000030517578, 'min': 53.189998626708984},
#    'wind': {'morningMax': 4.132086753845215,
#     'dayMax': 6.659361362457275,
#     'average': 4.029153347015381,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-09'}}},
#   {'date': '2018-01-10',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.469999313354492,
#     'min': 19.049999237060547,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6234.1552734375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.6500015258789, 'min': 37.22999954223633},
#    'wind': {'morningMax': 4.0785627365112305,
#     'dayMax': 4.733089447021484,
#     'average': 3.083989381790161,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-10'}}},
#   {'date': '2018-01-11',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.34000015258789,
#     'min': 20.459999084472656,
#     'units': 'C'},
#    'precipitation': {'amount': 1.2999999523162842, 'units': 'mm'},
#    'solar': {'amount': 5439.0712890625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 88.2300033569336, 'min': 52.2400016784668},
#    'wind': {'morningMax': 6.083805084228516,
#     'dayMax': 8.117996215820312,
#     'average': 4.513760089874268,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-11'}}},
#   {'date': '2018-01-12',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.239999771118164,
#     'min': 19.979999542236328,
#     'units': 'C'},
#    'precipitation': {'amount': 6.25, 'units': 'mm'},
#    'solar': {'amount': 3848.584228515625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 87.56999969482422, 'min': 54.189998626708984},
#    'wind': {'morningMax': 5.6911301612854,
#     'dayMax': 8.52195930480957,
#     'average': 4.046362400054932,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-12'}}},
#   {'date': '2018-01-13',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.3700008392334,
#     'min': 20.079999923706055,
#     'units': 'C'},
#    'precipitation': {'amount': 4.199999809265137, 'units': 'mm'},
#    'solar': {'amount': 5314.91162109375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 86.5199966430664, 'min': 56.79999923706055},
#    'wind': {'morningMax': 4.159970283508301,
#     'dayMax': 6.124366283416748,
#     'average': 4.05496883392334,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-13'}}},
#   {'date': '2018-01-14',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.360000610351562,
#     'min': 19.969999313354492,
#     'units': 'C'},
#    'precipitation': {'amount': 1.375, 'units': 'mm'},
#    'solar': {'amount': 4848.919921875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 88.31999969482422, 'min': 41.13999938964844},
#    'wind': {'morningMax': 4.586634159088135,
#     'dayMax': 6.121051788330078,
#     'average': 3.100982427597046,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-14'}}},
#   {'date': '2018-01-15',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.290000915527344,
#     'min': 20.540000915527344,
#     'units': 'C'},
#    'precipitation': {'amount': 0.5249999761581421, 'units': 'mm'},
#    'solar': {'amount': 5688.17822265625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.41999816894531, 'min': 46.810001373291016},
#    'wind': {'morningMax': 4.203273773193359,
#     'dayMax': 7.463432788848877,
#     'average': 4.535791397094727,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-15'}}},
#   {'date': '2018-01-16',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.760000228881836,
#     'min': 20.059999465942383,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6405.67724609375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 83.9000015258789, 'min': 36.93000030517578},
#    'wind': {'morningMax': 4.07953405380249,
#     'dayMax': 6.220948696136475,
#     'average': 4.028153419494629,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-16'}}},
#   {'date': '2018-01-17',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.219999313354492,
#     'min': 18.979999542236328,
#     'units': 'C'},
#    'precipitation': {'amount': 1.350000023841858, 'units': 'mm'},
#    'solar': {'amount': 6348.1572265625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 82.36000061035156, 'min': 33.5},
#    'wind': {'morningMax': 4.832797527313232,
#     'dayMax': 6.369110107421875,
#     'average': 3.091290235519409,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-17'}}},
#   {'date': '2018-01-18',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.899999618530273,
#     'min': 20.3700008392334,
#     'units': 'C'},
#    'precipitation': {'amount': 4.550000190734863, 'units': 'mm'},
#    'solar': {'amount': 5346.287109375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 88.72000122070312, 'min': 46.189998626708984},
#    'wind': {'morningMax': 2.2048234939575195,
#     'dayMax': 4.95876407623291,
#     'average': 3.0977835655212402,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-18'}}},
#   {'date': '2018-01-19',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.139999389648438,
#     'min': 20.34000015258789,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6509.6201171875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 93.51000213623047, 'min': 42.790000915527344},
#    'wind': {'morningMax': 4.226838111877441,
#     'dayMax': 5.7530083656311035,
#     'average': 3.5687248706817627,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-19'}}},
#   {'date': '2018-01-20',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 27.010000228881836,
#     'min': 19.8700008392334,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 3791.772705078125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 93.37000274658203, 'min': 54.41999816894531},
#    'wind': {'morningMax': 2.6505441665649414,
#     'dayMax': 7.212610721588135,
#     'average': 3.102863311767578,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-20'}}},
#   {'date': '2018-01-21',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.450000762939453,
#     'min': 19.889999389648438,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6188.00048828125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.12000274658203, 'min': 31.700000762939453},
#    'wind': {'morningMax': 7.519931793212891,
#     'dayMax': 7.586658477783203,
#     'average': 3.557677984237671,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-21'}}},
#   {'date': '2018-01-22',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.600000381469727,
#     'min': 19.610000610351562,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6282.365234375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 72.13999938964844, 'min': 34.459999084472656},
#    'wind': {'morningMax': 4.09644079208374,
#     'dayMax': 6.100443363189697,
#     'average': 2.631594657897949,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-22'}}},
#   {'date': '2018-01-23',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.940000534057617,
#     'min': 20.479999542236328,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6151.08203125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 90.91999816894531, 'min': 23.979999542236328},
#    'wind': {'morningMax': 5.651927947998047,
#     'dayMax': 7.051498889923096,
#     'average': 4.5457258224487305,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-23'}}},
#   {'date': '2018-01-24',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 27.260000228881836,
#     'min': 17.34000015258789,
#     'units': 'C'},
#    'precipitation': {'amount': 12.649999618530273, 'units': 'mm'},
#    'solar': {'amount': 5220.23828125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 96.45999908447266, 'min': 42.220001220703125},
#    'wind': {'morningMax': 5.140141010284424,
#     'dayMax': 9.16507339477539,
#     'average': 3.572382688522339,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-24'}}},
#   {'date': '2018-01-25',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 25.719999313354492,
#     'min': 18.649999618530273,
#     'units': 'C'},
#    'precipitation': {'amount': 4.125, 'units': 'mm'},
#    'solar': {'amount': 3817.825927734375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 94.51000213623047, 'min': 44.0},
#    'wind': {'morningMax': 3.482140064239502,
#     'dayMax': 6.7821526527404785,
#     'average': 3.087090015411377,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-25'}}},
#   {'date': '2018-01-26',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 27.219999313354492,
#     'min': 18.489999771118164,
#     'units': 'C'},
#    'precipitation': {'amount': 0.2750000059604645, 'units': 'mm'},
#    'solar': {'amount': 3954.529052734375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 92.9800033569336, 'min': 51.34000015258789},
#    'wind': {'morningMax': 3.9077672958374023,
#     'dayMax': 4.053159236907959,
#     'average': 2.1395463943481445,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-26'}}},
#   {'date': '2018-01-27',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.59000015258789,
#     'min': 18.940000534057617,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 5851.38671875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 90.8499984741211, 'min': 45.0},
#    'wind': {'morningMax': 4.601274490356445,
#     'dayMax': 6.250993251800537,
#     'average': 3.0965380668640137,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-27'}}},
#   {'date': '2018-01-28',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.989999771118164,
#     'min': 19.709999084472656,
#     'units': 'C'},
#    'precipitation': {'amount': 0.5249999761581421, 'units': 'mm'},
#    'solar': {'amount': 6500.88037109375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.11000061035156, 'min': 42.130001068115234},
#    'wind': {'morningMax': 4.26787805557251,
#     'dayMax': 4.778787136077881,
#     'average': 3.5757272243499756,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-28'}}},
#   {'date': '2018-01-29',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.020000457763672,
#     'min': 20.200000762939453,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6667.681640625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 96.22000122070312, 'min': 44.41999816894531},
#    'wind': {'morningMax': 4.093509674072266,
#     'dayMax': 5.3336286544799805,
#     'average': 3.5748438835144043,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-29'}}},
#   {'date': '2018-01-30',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.829999923706055,
#     'min': 20.059999465942383,
#     'units': 'C'},
#    'precipitation': {'amount': 0.3499999940395355, 'units': 'mm'},
#    'solar': {'amount': 6573.04833984375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 91.5999984741211, 'min': 36.540000915527344},
#    'wind': {'morningMax': 2.864314317703247,
#     'dayMax': 5.924370765686035,
#     'average': 3.0271403789520264,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-30'}}},
#   {'date': '2018-01-31',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.469999313354492,
#     'min': 19.809999465942383,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6644.03955078125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 90.66999816894531, 'min': 39.63999938964844},
#    'wind': {'morningMax': 3.558391571044922,
#     'dayMax': 7.17323112487793,
#     'average': 3.5488293170928955,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-31'}}},
#   {'date': '2018-02-01',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 29.850000381469727,
#     'min': 19.950000762939453,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6816.3515625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 82.44999694824219, 'min': 35.400001525878906},
#    'wind': {'morningMax': 3.150857448577881,
#     'dayMax': 4.974684715270996,
#     'average': 3.5767948627471924,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-01'}}},
#   {'date': '2018-02-02',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.850000381469727,
#     'min': 20.920000076293945,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6789.0068359375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 86.3499984741211, 'min': 31.719999313354492},
#    'wind': {'morningMax': 3.2033703327178955,
#     'dayMax': 7.28645133972168,
#     'average': 3.6068966388702393,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-02'}}},
#   {'date': '2018-02-03',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.309999465942383,
#     'min': 20.610000610351562,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6757.1337890625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 98.05000305175781, 'min': 35.279998779296875},
#    'wind': {'morningMax': 4.1738786697387695,
#     'dayMax': 6.978455543518066,
#     'average': 3.558465003967285,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-03'}}},
#   {'date': '2018-02-04',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.299999237060547,
#     'min': 20.709999084472656,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6808.86376953125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 90.79000091552734, 'min': 33.93000030517578},
#    'wind': {'morningMax': 5.089956283569336,
#     'dayMax': 6.655291557312012,
#     'average': 3.5700719356536865,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-04'}}},
#   {'date': '2018-02-05',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.40999984741211,
#     'min': 21.440000534057617,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 6349.92236328125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 86.98999786376953, 'min': 32.18000030517578},
#    'wind': {'morningMax': 3.18030047416687,
#     'dayMax': 5.974389553070068,
#     'average': 3.580711603164673,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-05'}}},
#   {'date': '2018-02-06',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.049999237060547,
#     'min': 22.100000381469727,
#     'units': 'C'},
#    'precipitation': {'amount': 0.0, 'units': 'mm'},
#    'solar': {'amount': 5317.5908203125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 84.94999694824219, 'min': 41.20000076293945},
#    'wind': {'morningMax': 2.7402970790863037,
#     'dayMax': 5.782005786895752,
#     'average': 2.615422010421753,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-06'}}},
#   {'date': '2018-02-07',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.170000076293945,
#     'min': 22.110000610351562,
#     'units': 'C'},
#    'precipitation': {'amount': 1.25, 'units': 'mm'},
#    'solar': {'amount': 5136.6318359375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 80.48999786376953, 'min': 43.91999816894531},
#    'wind': {'morningMax': 4.631841659545898,
#     'dayMax': 7.0728631019592285,
#     'average': 4.0550079345703125,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-07'}}},
#   {'date': '2018-02-08',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.770000457763672, 'min': 22.75, 'units': 'C'},
#    'precipitation': {'amount': 1.75, 'units': 'mm'},
#    'solar': {'amount': 6545.84619140625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 75.36000061035156, 'min': 30.649999618530273},
#    'wind': {'morningMax': 5.126908302307129,
#     'dayMax': 7.048879623413086,
#     'average': 4.07135009765625,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-08'}}},
#   {'date': '2018-02-09',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.56999969482422,
#     'min': 21.209999084472656,
#     'units': 'C'},
#    'precipitation': {'amount': 1.375, 'units': 'mm'},
#    'solar': {'amount': 4396.60986328125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 78.37999725341797, 'min': 21.709999084472656},
#    'wind': {'morningMax': 6.2741827964782715,
#     'dayMax': 6.3381571769714355,
#     'average': 3.601402521133423,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-09'}}},
#   {'date': '2018-02-10',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.989999771118164,
#     'min': 20.920000076293945,
#     'units': 'C'},
#    'precipitation': {'amount': 0.17499999701976776, 'units': 'mm'},
#    'solar': {'amount': 5814.16650390625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 75.4000015258789, 'min': 26.219999313354492},
#    'wind': {'morningMax': 3.1813712120056152,
#     'dayMax': 8.149292945861816,
#     'average': 4.083006381988525,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-10'}}},
#   {'date': '2018-02-11',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.920000076293945,
#     'min': 21.049999237060547,
#     'units': 'C'},
#    'precipitation': {'amount': 1.75, 'units': 'mm'},
#    'solar': {'amount': 6780.6630859375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 87.44000244140625, 'min': 44.06999969482422},
#    'wind': {'morningMax': 4.173047065734863,
#     'dayMax': 6.975607872009277,
#     'average': 4.072981834411621,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-11'}}},
#   {'date': '2018-02-12',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.110000610351562,
#     'min': 21.600000381469727,
#     'units': 'C'},
#    'precipitation': {'amount': 8.125, 'units': 'mm'},
#    'solar': {'amount': 5940.07861328125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 80.87000274658203, 'min': 32.68000030517578},
#    'wind': {'morningMax': 3.7339370250701904,
#     'dayMax': 5.295799255371094,
#     'average': 3.1200413703918457,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-12'}}},
#   {'date': '2018-02-13',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 30.760000228881836,
#     'min': 21.700000762939453,
#     'units': 'C'},
#    'precipitation': {'amount': 0.17499999701976776, 'units': 'mm'},
#    'solar': {'amount': 6008.109375, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 86.61000061035156, 'min': 29.100000381469727},
#    'wind': {'morningMax': 4.265058994293213,
#     'dayMax': 5.7706475257873535,
#     'average': 4.103724956512451,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-13'}}},
#   {'date': '2018-02-14',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.610000610351562,
#     'min': 21.850000381469727,
#     'units': 'C'},
#    'precipitation': {'amount': 24.600000381469727, 'units': 'mm'},
#    'solar': {'amount': 6730.185546875, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 87.01000213623047, 'min': 31.649999618530273},
#    'wind': {'morningMax': 5.181136131286621,
#     'dayMax': 6.531235694885254,
#     'average': 4.567183494567871,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-14'}}},
#   {'date': '2018-02-15',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 33.709999084472656,
#     'min': 22.020000457763672,
#     'units': 'C'},
#    'precipitation': {'amount': 3.325000047683716, 'units': 'mm'},
#    'solar': {'amount': 6641.85791015625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 94.43000030517578, 'min': 24.6299991607666},
#    'wind': {'morningMax': 3.1968154907226562,
#     'dayMax': 8.672040939331055,
#     'average': 3.1278023719787598,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-15'}}},
#   {'date': '2018-02-16',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 32.7599983215332,
#     'min': 21.1200008392334,
#     'units': 'C'},
#    'precipitation': {'amount': 7.150000095367432, 'units': 'mm'},
#    'solar': {'amount': 6735.0390625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 81.01000213623047, 'min': 35.40999984741211},
#    'wind': {'morningMax': 4.656480312347412,
#     'dayMax': 6.054121494293213,
#     'average': 3.593729257583618,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-16'}}},
#   {'date': '2018-02-17',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 32.290000915527344,
#     'min': 21.540000915527344,
#     'units': 'C'},
#    'precipitation': {'amount': 0.32499998807907104, 'units': 'mm'},
#    'solar': {'amount': 6947.759765625, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 84.13999938964844, 'min': 34.93000030517578},
#    'wind': {'morningMax': 5.647768497467041,
#     'dayMax': 6.593201160430908,
#     'average': 5.038288116455078,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-17'}}},
#   {'date': '2018-02-18',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 31.010000228881836,
#     'min': 22.040000915527344,
#     'units': 'C'},
#    'precipitation': {'amount': 2.75, 'units': 'mm'},
#    'solar': {'amount': 6614.783203125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 81.27999877929688, 'min': 26.709999084472656},
#    'wind': {'morningMax': 3.12237811088562,
#     'dayMax': 5.927340030670166,
#     'average': 3.5829527378082275,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-18'}}},
#   {'date': '2018-02-19',
#    'location': {'latitude': 0.25, 'longitude': 32.0},
#    'temperatures': {'max': 28.670000076293945,
#     'min': 19.1200008392334,
#     'units': 'C'},
#    'precipitation': {'amount': 6.724999904632568, 'units': 'mm'},
#    'solar': {'amount': 4865.57470703125, 'units': 'Wh/m^2'},
#    'relativeHumidity': {'max': 85.08999633789062, 'min': 46.619998931884766},
#    'wind': {'morningMax': 5.670000076293945,
#     'dayMax': 7.35129976272583,
#     'average': 3.57957124710083,
#     'units': 'm/sec'},
#    '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-02-19'}}}],
#  '_links': {'self': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-01,2018-12-31?limit=50'},
#   'next': {'href': '/v2/weather/locations/0.25,32/observations/2018-01-01,2018-12-31?limit=50&offset=50'}}}

# %%
response.json().get("_links").get("next").get("href")
# Out:
# '/v2/weather/locations/0.25,32/observations/2018-01-01,2018-12-31?limit=50&offset=50'

# %%
api_request = api_host + "/v2/weather/locations/0.32,32.6/forecasts/2019-02-04, 2019-02-04" # somewhere in the middle of kampala
response = requests.get(api_request, headers=api_header)
response.json()
# Out:
# {'forecasts': [{'date': '2019-02-04',
#    'location': {'latitude': 0.32, 'longitude': 32.5999985},
#    'forecast': [{'startTime': '2019-02-04T00:00:00+00:00',
#      'endTime': '2019-02-04T00:59:59+00:00',
#      'conditionsCode': '811',
#      'conditionsText': 'Partly Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 19.206308364868164,
#       'max': 19.576309204101562,
#       'min': 19.18130874633789,
#       'units': 'C'},
#      'precipitation': {'chance': 60.000003814697266,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 56.0, 'sunshine': 44.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 91.01874542236328,
#       'max': None,
#       'min': None},
#      'wind': {'average': 0.17775203348109025,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 17.874635708191697, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 21.8563289642334,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.753690719604492,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.312362670898438,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.899999618530273,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.69999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.200000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T01:00:00+00:00',
#      'endTime': '2019-02-04T01:59:59+00:00',
#      'conditionsCode': '811',
#      'conditionsText': 'Partly Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 19.206308364868164,
#       'max': 20.440956115722656,
#       'min': 19.171308517456055,
#       'units': 'C'},
#      'precipitation': {'chance': 52.499996185302734,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 56.0, 'sunshine': 44.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 91.01874542236328,
#       'max': None,
#       'min': None},
#      'wind': {'average': 0.17775203348109025,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.297070348600748, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 21.8563289642334,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.753690719604492,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.312362670898438,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.899999618530273,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.69999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.200000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T02:00:00+00:00',
#      'endTime': '2019-02-04T02:59:59+00:00',
#      'conditionsCode': '811',
#      'conditionsText': 'Partly Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 19.206308364868164,
#       'max': 22.17025375366211,
#       'min': 19.151308059692383,
#       'units': 'C'},
#      'precipitation': {'chance': 37.5, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 56.0, 'sunshine': 44.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 91.01874542236328,
#       'max': None,
#       'min': None},
#      'wind': {'average': 0.17775203348109025,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 19.14191785766796, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 21.8563289642334,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.753690719604492,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.312362670898438,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.899999618530273,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.69999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.200000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T03:00:00+00:00',
#      'endTime': '2019-02-04T03:59:59+00:00',
#      'conditionsCode': '921',
#      'conditionsText': 'Mostly Cloudy Night, Light Rain, Light Wind/Calm',
#      'temperatures': {'value': 21.06056022644043,
#       'max': 23.899551391601562,
#       'min': 19.131309509277344,
#       'units': 'C'},
#      'precipitation': {'chance': 22.5, 'amount': 0.0625, 'units': 'mm'},
#      'sky': {'cloudCover': 68.0, 'sunshine': 32.0},
#      'solar': {'amount': 130.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 83.28274536132812,
#       'max': None,
#       'min': None},
#      'wind': {'average': 0.7125015276219966,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.559940297067943, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 21.856321334838867,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.727643966674805,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.315410614013672,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.874406814575195,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.96666717529297,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.69999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.200000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T04:00:00+00:00',
#      'endTime': '2019-02-04T04:59:59+00:00',
#      'conditionsCode': '921',
#      'conditionsText': 'Mostly Cloudy Night, Light Rain, Light Wind/Calm',
#      'temperatures': {'value': 22.914812088012695,
#       'max': 25.4905948638916,
#       'min': 20.11262321472168,
#       'units': 'C'},
#      'precipitation': {'chance': 15.000000953674316,
#       'amount': 0.0625,
#       'units': 'mm'},
#      'sky': {'cloudCover': 68.0, 'sunshine': 32.0},
#      'solar': {'amount': 130.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 75.54674530029297,
#       'max': None,
#       'min': None},
#      'wind': {'average': 1.2842573981718814,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.254317253865295, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 21.85631561279297,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.701595306396484,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.318456649780273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.874967575073242,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 21.03333282470703,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.69999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.200000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T05:00:00+00:00',
#      'endTime': '2019-02-04T05:59:59+00:00',
#      'conditionsCode': '921',
#      'conditionsText': 'Mostly Cloudy Night, Light Rain, Light Wind/Calm',
#      'temperatures': {'value': 24.769062042236328,
#       'max': 26.943387985229492,
#       'min': 22.095252990722656,
#       'units': 'C'},
#      'precipitation': {'chance': 15.000000953674316,
#       'amount': 0.0625,
#       'units': 'mm'},
#      'sky': {'cloudCover': 68.0, 'sunshine': 32.0},
#      'solar': {'amount': 130.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 67.81074523925781,
#       'max': None,
#       'min': None},
#      'wind': {'average': 1.8591856400716689,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.181260986597824, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 21.856307983398438,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.675546646118164,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.321504592895508,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.875526428222656,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 21.100000381469727,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.69999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.200000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T06:00:00+00:00',
#      'endTime': '2019-02-04T06:59:59+00:00',
#      'conditionsCode': '421',
#      'conditionsText': 'Mostly Cloudy Day, Light Rain, Light Wind/Calm',
#      'temperatures': {'value': 29.469921112060547,
#       'max': 29.657032012939453,
#       'min': 25.099903106689453,
#       'units': 'C'},
#      'precipitation': {'chance': 70.0,
#       'amount': 0.0416666679084301,
#       'units': 'mm'},
#      'sky': {'cloudCover': 73.0, 'sunshine': 27.0},
#      'solar': {'amount': 760.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 45.0992317199707,
#       'max': None,
#       'min': None},
#      'wind': {'average': 3.608250266825335,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 14.435189520696762, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.869556427001953,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.675546646118164,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.322362899780273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.80000114440918,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.5,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.100000381469727,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T07:00:00+00:00',
#      'endTime': '2019-02-04T07:59:59+00:00',
#      'conditionsCode': '421',
#      'conditionsText': 'Mostly Cloudy Day, Light Rain, Light Wind/Calm',
#      'temperatures': {'value': 29.469921112060547,
#       'max': 29.74203109741211,
#       'min': 25.099903106689453,
#       'units': 'C'},
#      'precipitation': {'chance': 64.16666412353516,
#       'amount': 0.0416666679084301,
#       'units': 'mm'},
#      'sky': {'cloudCover': 73.0, 'sunshine': 27.0},
#      'solar': {'amount': 760.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 45.0992317199707,
#       'max': None,
#       'min': None},
#      'wind': {'average': 3.608250266825335,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 14.473717751211835, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.869556427001953,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.675546646118164,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.322362899780273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.80000114440918,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.5,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.100000381469727,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T08:00:00+00:00',
#      'endTime': '2019-02-04T08:59:59+00:00',
#      'conditionsCode': '421',
#      'conditionsText': 'Mostly Cloudy Day, Light Rain, Light Wind/Calm',
#      'temperatures': {'value': 29.469921112060547,
#       'max': 29.912031173706055,
#       'min': 25.099903106689453,
#       'units': 'C'},
#      'precipitation': {'chance': 52.499996185302734,
#       'amount': 0.0416666679084301,
#       'units': 'mm'},
#      'sky': {'cloudCover': 73.0, 'sunshine': 27.0},
#      'solar': {'amount': 760.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 45.0992317199707,
#       'max': None,
#       'min': None},
#      'wind': {'average': 3.608250266825335,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 14.55077333786201, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.869556427001953,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.675546646118164,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.322362899780273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.80000114440918,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.5,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.100000381469727,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T09:00:00+00:00',
#      'endTime': '2019-02-04T09:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 29.590234756469727,
#       'max': 30.08203125,
#       'min': 25.099903106689453,
#       'units': 'C'},
#      'precipitation': {'chance': 40.83333206176758,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 79.0, 'sunshine': 21.0},
#      'solar': {'amount': 1000.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 45.466156005859375,
#       'max': None,
#       'min': None},
#      'wind': {'average': 3.872592151918458,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 14.753479304231288, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 24.48250961303711,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.70553970336914,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.322071075439453,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.700000762939453,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.46666717529297,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.066665649414062,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T10:00:00+00:00',
#      'endTime': '2019-02-04T10:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 29.710546493530273,
#       'max': 30.09453773498535,
#       'min': 25.319971084594727,
#       'units': 'C'},
#      'precipitation': {'chance': 30.000001907348633,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 79.0, 'sunshine': 21.0},
#      'solar': {'amount': 1000.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 45.83307647705078,
#       'max': None,
#       'min': None},
#      'wind': {'average': 4.143811648202534,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 14.983858512012116, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 25.0954647064209,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.73553466796875,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.32177734375,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.600000381469727,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.433332443237305,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.03333282470703,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T11:00:00+00:00',
#      'endTime': '2019-02-04T11:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 29.830860137939453,
#       'max': 29.94955062866211,
#       'min': 25.760107040405273,
#       'units': 'C'},
#      'precipitation': {'chance': 20.0, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 79.0, 'sunshine': 21.0},
#      'solar': {'amount': 1000.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 46.20000076293945,
#       'max': None,
#       'min': None},
#      'wind': {'average': 4.420643505497992,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 15.242004064162106, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 25.708417892456055,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.765527725219727,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.321483612060547,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.87384796142578,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.5,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.399999618530273,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T12:00:00+00:00',
#      'endTime': '2019-02-04T12:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 28.704010009765625,
#       'max': 29.804563522338867,
#       'min': 26.200244903564453,
#       'units': 'C'},
#      'precipitation': {'chance': 10.0, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 82.0, 'sunshine': 18.0},
#      'solar': {'amount': 580.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 51.599998474121094,
#       'max': None,
#       'min': None},
#      'wind': {'average': 4.25285833134572,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 17.111015823468904, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 25.823991775512695,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.798866271972656,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.32177734375,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.874414443969727,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.433334350585938,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.366666793823242,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T13:00:00+00:00',
#      'endTime': '2019-02-04T13:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 27.57716178894043,
#       'max': 29.731660842895508,
#       'min': 25.74509048461914,
#       'units': 'C'},
#      'precipitation': {'chance': 4.1666669845581055,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 82.0, 'sunshine': 18.0},
#      'solar': {'amount': 580.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 57.0, 'max': None, 'min': None},
#      'wind': {'average': 4.093551796269505,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.446888824089935, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 25.939563751220703,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.83220672607422,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.322071075439453,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.874980926513672,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.366666793823242,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.33333396911621,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T14:00:00+00:00',
#      'endTime': '2019-02-04T14:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 26.4503116607666,
#       'max': 29.7308406829834,
#       'min': 24.3946475982666,
#       'units': 'C'},
#      'precipitation': {'chance': 2.5, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 82.0, 'sunshine': 18.0},
#      'solar': {'amount': 580.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 62.400001525878906,
#       'max': None,
#       'min': None},
#      'wind': {'average': 3.943751748453653,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 19.262593414325266, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 26.055137634277344,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.86554718017578,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.322362899780273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.875547409057617,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.299999237060547,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.299999237060547,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T15:00:00+00:00',
#      'endTime': '2019-02-04T15:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 25.113203048706055,
#       'max': 29.730018615722656,
#       'min': 23.044206619262695,
#       'units': 'C'},
#      'precipitation': {'chance': 0.8333333730697632,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 78.0, 'sunshine': 22.0},
#      'solar': {'amount': 40.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 67.36666870117188,
#       'max': None,
#       'min': None},
#      'wind': {'average': 3.3095611287229305,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 19.855264688923555, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 25.67563819885254,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.885547637939453,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.325103759765625,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.878320693969727,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.266666412353516,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.27327537536621,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T16:00:00+00:00',
#      'endTime': '2019-02-04T16:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 23.776094436645508,
#       'max': 28.518577575683594,
#       'min': 22.283973693847656,
#       'units': 'C'},
#      'precipitation': {'chance': 0.8333333730697632,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 78.0, 'sunshine': 22.0},
#      'solar': {'amount': 40.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 72.33333587646484,
#       'max': None,
#       'min': None},
#      'wind': {'average': 2.6931056277297434,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 20.061094154676738, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 25.296138763427734,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.905546188354492,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.327844619750977,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.881093978881836,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.233333587646484,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.246549606323242,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T17:00:00+00:00',
#      'endTime': '2019-02-04T17:59:59+00:00',
#      'conditionsCode': '411',
#      'conditionsText': 'Mostly Cloudy Day, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 22.438983917236328,
#       'max': 26.096513748168945,
#       'min': 22.113954544067383,
#       'units': 'C'},
#      'precipitation': {'chance': 2.5, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 78.0, 'sunshine': 22.0},
#      'solar': {'amount': 40.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 77.30000305175781,
#       'max': None,
#       'min': None},
#      'wind': {'average': 2.1099874487562786,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 19.883345505077802, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 24.916641235351562,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.925546646118164,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.330585479736328,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.883867263793945,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.219823837280273,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T18:00:00+00:00',
#      'endTime': '2019-02-04T18:59:59+00:00',
#      'conditionsCode': 'A11',
#      'conditionsText': 'Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 22.25713539123535,
#       'max': 23.674449920654297,
#       'min': 21.94393539428711,
#       'units': 'C'},
#      'precipitation': {'chance': 4.1666669845581055,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 90.0, 'sunshine': 10.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 77.4000015258789,
#       'max': None,
#       'min': None},
#      'wind': {'average': 2.1192655664644477,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.648514844702554, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 24.595500946044922,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.923377990722656,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.334510803222656,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.883867263793945,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.246549606323242,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T19:00:00+00:00',
#      'endTime': '2019-02-04T19:59:59+00:00',
#      'conditionsCode': 'A11',
#      'conditionsText': 'Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 22.075286865234375,
#       'max': 22.46356773376465,
#       'min': 21.62725830078125,
#       'units': 'C'},
#      'precipitation': {'chance': 11.666666984558105,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 90.0, 'sunshine': 10.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 77.5, 'max': None, 'min': None},
#      'wind': {'average': 2.142181566364591,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 17.928948147108297, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 24.274362564086914,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.92121124267578,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.338438034057617,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.883867263793945,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.27327537536621,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T20:00:00+00:00',
#      'endTime': '2019-02-04T20:59:59+00:00',
#      'conditionsCode': 'A11',
#      'conditionsText': 'Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 21.8934383392334,
#       'max': 22.4638671875,
#       'min': 21.163925170898438,
#       'units': 'C'},
#      'precipitation': {'chance': 25.0, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 90.0, 'sunshine': 10.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 77.5999984741211,
#       'max': None,
#       'min': None},
#      'wind': {'average': 2.178304815923025,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 17.725030520751172, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.953222274780273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.919042587280273,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.342363357543945,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.883867263793945,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.299999237060547,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T21:00:00+00:00',
#      'endTime': '2019-02-04T21:59:59+00:00',
#      'conditionsCode': 'A11',
#      'conditionsText': 'Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 21.431503295898438,
#       'max': 22.46416664123535,
#       'min': 20.700592041015625,
#       'units': 'C'},
#      'precipitation': {'chance': 38.33333206176758,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 96.0, 'sunshine': 4.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 80.30000305175781,
#       'max': None,
#       'min': None},
#      'wind': {'average': 0.9965826542211392,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.04373294054129, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.659257888793945,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.904544830322266,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.342363357543945,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.88442039489746,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.266666412353516,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T22:00:00+00:00',
#      'endTime': '2019-02-04T22:59:59+00:00',
#      'conditionsCode': 'A11',
#      'conditionsText': 'Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 20.96957015991211,
#       'max': 22.137344360351562,
#       'min': 20.280263900756836,
#       'units': 'C'},
#      'precipitation': {'chance': 46.66666793823242,
#       'amount': 0.0,
#       'units': 'mm'},
#      'sky': {'cloudCover': 96.0, 'sunshine': 4.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 83.0, 'max': None, 'min': None},
#      'wind': {'average': 0.4244955548898594,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.205927581033098, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.365293502807617,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.890045166015625,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.342363357543945,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.884973526000977,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.233333587646484,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]},
#     {'startTime': '2019-02-04T23:00:00+00:00',
#      'endTime': '2019-02-04T23:59:59+00:00',
#      'conditionsCode': 'A11',
#      'conditionsText': 'Cloudy Night, No Rain, Light Wind/Calm',
#      'temperatures': {'value': 20.50763702392578,
#       'max': 21.4833984375,
#       'min': 19.902938842773438,
#       'units': 'C'},
#      'precipitation': {'chance': 50.0, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 96.0, 'sunshine': 4.0},
#      'solar': {'amount': 0.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 85.69999694824219,
#       'max': None,
#       'min': None},
#      'wind': {'average': 1.5185749742490158,
#       'max': None,
#       'min': None,
#       'units': 'm/sec'},
#      'dewPoint': {'amount': 18.211003205493856, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 23.071327209472656,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 22.875547409057617,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 22.342363357543945,
#        'max': None,
#        'min': None,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 21.885526657104492,
#        'max': None,
#        'min': None,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 21.19999885559082,
#        'max': None,
#        'min': None},
#       {'depth': '0.4-1 m below ground',
#        'average': 20.0,
#        'max': None,
#        'min': None},
#       {'depth': '1-2 m below ground',
#        'average': 18.899999618530273,
#        'max': None,
#        'min': None}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/0.32,32.5999985/forecasts/2019-02-04'}}}],
#  '_links': {'self': {'href': '/v2/weather/locations/0.32,32.5999985/forecasts/2019-02-04,2019-02-04'}}}

# %%
# Out:
# {'date': '2018-01-01',
#  'location': {'latitude': 0.32, 'longitude': 32.5999985},
#  'temperatures': {'max': 26.690000534057617,
#   'min': 19.959999084472656,
#   'units': 'C'},
#  'precipitation': {'amount': 1.4476732015609741, 'units': 'mm'},
#  'solar': {'amount': 3714.357666015625, 'units': 'Wh/m^2'},
#  'relativeHumidity': {'max': 90.72000122070312, 'min': 57.04999923706055},
#  'wind': {'morningMax': 3.633565902709961,
#   'dayMax': 5.147958755493164,
#   'average': 2.5669796466827393,
#   'units': 'm/sec'},
#  '_links': {'self': {'href': '/v2/weather/locations/0.32,32.5999985/observations/2018-01-01'}}}

# %%
# Try the same for the current conditions
api_request = api_host + "/v2/weather/locations/0.32,32.6/currentconditions" # somewhere in the middle of kampala
response = requests.get(api_request, headers=api_header)

# %%
api_request = api_host  + "/v2/fields"

# %%
response = requests.get(api_request, headers=api_header)
response
# Out:
# <Response [200]>

# %%
# works
response.json()
# Out:
# {'fields': [], '_links': {'self': {'href': '/v2/fields'}}}

# %% [markdown]
# ## Introduction to aWhere fields:
#
#
# ### The most convenient way to work with weather api in agriculture context is to define a plantation or a "field" basically creating point of interest rather than dividing the country into grid
#
# #### You define a field by submiting a post request with content:
# ```POST /v2/fields```
# ```json
# {
#     "id": "{fieldId}",
#     "name":"{fieldName}",
#     "farmId":"{farmId}",
#     "acres":{acres},
#     "centerPoint":{
#         "latitude":{latitude},
#         "longitude":{longitude},
#         }
# }
# ```
# #### and with headers:
# Authorization	Bearer {token}
# Content-Type	application/json
#
# #### and then querying the api by fieldID
# https://api.awhere.com/v2/fields/{fieldId}
#
# #### after that you can create plantings on the fields you have created.
#
# by ```POST /v2/agronomics/fields/{fieldId}/plantings```
#
# and context
# ```json
# {
#     "crop":"{crop}",
#     "plantingDate":"{plantingDate}",
#     "projections":{
#         "yield":{
#             "amount":{projectedYieldAmount},
#             "units":"{projectedYieldUnits}",
#             },
#         "harvestDate":"{projectedHarvestDate}"
#         },
#     "yield":{
#         "amount":{yieldAmount},
#         "units":"{yieldUnits}",
#         },
#     "harvestDate":"{harvestDate}"
# }
# ```
# ##### Querying field and planting id will return you following dictionary
#
# ```GET /v2/agronomics/plantings/{plantingId}```
# ```json
# {
#     "id": {id},
#     "crop":"{cropId}",
#     "field":"{fieldId}",
#     "plantingDate":"{plantingDate}",
#     "projections":{
#         "yield":{
#             "amount":{projectedYieldAmount},
#             "units":"{projectedYieldUnits}",
#             }
#         "harvestDate":"{projectedHarvestDate}"
#         }
#     "yield":{
#         "amount":{yieldAmount},
#         "units":"{yieldUnits}",
#         },
#     "harvestDate":"{harvestDate}",
#     "_links":{
#         "self":{"href":"{plantingSelfLink}"},
#         "curies":[{
#             "name":"awhere",
#             "href":"http://awhere.com/rels/{rel}",
#             "templated":true
#             }],
#         "awhere:field":{"href":"{fieldLink}"}
#         "awhere:crop":{"href":"{cropLink}"}
#     }
# }
# ```

# %%
# getting info out
api_request = api_host + "/v2/weather/locations/0.25,32/forecasts/2019-02-04" # somewhere in the middle of kampala

# %%
response = requests.get(api_request, headers = api_header)

# %%
response.json()
# Out:
# {'statusCode': 401,
#  'statusName': 'Unauthorized',
#  'errorId': '',
#  'simpleMessage': 'API Access Expired',
#  'detailedMessage': 'There is a problem with the access token being used for this request. Either it is missing, invalid for the API request, or has expired. Please generate a new access token and try the request again.'}

# %%
import json
import os

# %%
api_request = api_host + "/v2/weather/locations/0.25,32/currentconditions"
response = requests.get(api_request, headers = api_header)
data = response.json()

# %%
# Out:
# {'dateTime': '2019-02-04T18:30:00+03:00',
#  'location': {'latitude': 0.25,
#   'longitude': 32,
#   'nearestStation': {'distance': 55.535, 'units': 'km', 'bearing': 116}},
#  'conditionsCode': 'XX2',
#  'conditionsText': 'Moderate Wind',
#  'temperature': {'amount': 27, 'units': 'C'},
#  'precipitation': {'amount': None, 'units': 'mm'},
#  'solar': {'amount': 113, 'units': 'Wh/m^2'},
#  'relativeHumidity': {'amount': 62},
#  'wind': {'amount': 4.722226,
#   'units': 'm/sec',
#   'bearing': 200,
#   'direction': 'SSW'},
#  '_links': {'self': {'href': '/v2/weather/locations/0.25,32/currentconditions'}}}
